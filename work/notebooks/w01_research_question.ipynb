# %% [markdown]
# <a href="https://colab.research.google.com/github/NoorDataAnalyst/flyrank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing the Learning-to-Rank & Traffic Loss Prioritization lane. This lane bridges information retrieval and practical SEO decision-making. Rather than treating page degradation as a simple binary classification problem, LTR allows us to rank pages by their urgency of traffic decay. This matches real-world workflows where content teams have limited bandwidth and need to triage the most critical pages first.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Unit of Analysis: A page-week observation representing an individual URL's performance metrics over a specific weekly window.
# Decision Improved: Deciding which content assets require immediate auditing, keyword refreshing, or technical intervention to halt traffic erosion.
# Action Taken: SEO managers and content editors review the top-ranked pages generated by the model output and allocate human resources to update those specific URLs.
# Cost of a Wrong Call: A false positive wastes editorial hours optimizing a stable page that didn't need intervention; a false negative means missing a high-value page whose traffic decay goes unnoticed until it severely impacts revenue or visibility.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import getpass
import duckdb

# Prompt securely for your token (so it doesn't leak in public notebooks)
HF_TOKEN = getpass.getpass("Paste your Hugging Face READ token: ")

# Connect DuckDB directly to Hugging Face
con = duckdb.connect()
con.execute(f"CREATE OR REPLACE SECRET hf (TYPE huggingface, TOKEN '{HF_TOKEN}')")

# Set up access paths for the FlyRank dataset tables
REL = 'hf://datasets/FlyRank/internship-warehouse'
TABLES = {
    'dim_clients': f"read_parquet('{REL}/dim_clients.parquet')",
    'dim_content': f"read_parquet('{REL}/dim_content.parquet')",
    'fact_daily_sample': f"read_parquet('{REL}/fact_content_daily_performance_sample.parquet')",
    'fact_query_90d': f"read_parquet('{REL}/fact_content_query_90d.parquet')"
}

# Verify connection by counting sample rows
for name, src in TABLES.items():
    n = con.sql(f'SELECT COUNT(*) FROM {src}').fetchone()[0]
    print(f'{name:20} {n:>12,} rows')
# Out:
# Paste your Hugging Face READ token: ··········
# dim_clients                   104 rows
# dim_content               519,606 rows
# fact_daily_sample      11,694,072 rows
# fact_query_90d          2,414,248 rows

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# Our findings provide observed, directional, and decision-support insights. The model measures historical correlations between feature shifts (such as content age, engagement metrics, and historical volatility) and subsequent traffic decay patterns. We explicitly cannot claim causal proof (e.g., proving that a specific edit directly caused a ranking recovery) nor can we claim to be "predicting Google", given that search engines rely on external proprietary ranking signals that are outside our dataset's visibility.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✔] Every section above is filled — markdown thinking AND the code that backs it
# - [✔] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✔] No client names, URLs, or private queries anywhere
# - [✔] My claims use careful words: observed, measured, directional, decision-support
# - [✔] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
